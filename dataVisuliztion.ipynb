# %%
# import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
"before"
data={'EMCI': [ 204], 'LMCI': [61], 'MCI':[ 196], 'AD': [145], 'CN': [486]}
x1=[204, 61, 196, 145, 486]
lable=['EMCI', 'LMCI', 'MCI', 'AD', 'CN']
# df=pd.DataFrame.from_dict(data)
486
"after"
[{'EMCI': 486}, {'LMCI': 486}, {'MCI': 486}, {'AD': 486}, {'CN': 486}]
x2=[486,486,486,486,486]

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1,2,1)
plt.bar(lable,x1)
plt.title("before")
plt.subplot(1,2,2)
plt.bar(lable,x2)
plt.title("after")
plt.show()

# %%
ten_fold_lable=[]
for i in range(10):
    ten_fold_lable.append("Fold "+str(i+1))
ten_fold_lable
# Out:
# ['Fold 1',
#  'Fold 2',
#  'Fold 3',
#  'Fold 4',
#  'Fold 5',
#  'Fold 6',
#  'Fold 7',
#  'Fold 8',
#  'Fold 9',
#  'Fold 10']

# %%
ten_fold_rf=[0.71584699, 0.68852459, 0.71978022, 0.74175824, 0.67582418,
       0.68681319, 0.66483516, 0.67582418, 0.73076923, 0.71978022]

plt.figure(figsize=(10,5))
plt.plot(ten_fold_lable,ten_fold_rf)
plt.title("Random Forest")
plt.show()

# %%
ten_fold_knn=[0.64480874, 0.67213115, 0.7032967 , 0.67582418, 0.68131868,
       0.66483516, 0.57692308, 0.68681319, 0.67032967, 0.67032967]

plt.figure(figsize=(10,5))
plt.plot(ten_fold_lable,ten_fold_knn)
plt.title("K-Nearest Neighbors")
plt.show()

# %%
ten_fold_svm=[0.56725146, 0.63529412, 0.62941176, 0.58235294, 0.57647059,
       0.6       , 0.61764706, 0.57647059, 0.52352941, 0.65294118]
plt.figure(figsize=(10,5))
plt.plot(ten_fold_lable,ten_fold_svm)
plt.title("Support vector machine")
plt.show()

# %%
algo_names=["RF","KNN","SVM","ANN","CNN"]
time=[15.1,17.7,49.2,60,300]
#knn .3 actual

plt.bar(algo_names,time)
plt.title("Time")
plt.show()
